# %% [markdown]
# <a href="https://colab.research.google.com/github/EdmundoMarquez/AnalisisDatos_IA/blob/main/Hands_On_Introducci%C3%B3n_a_las_Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **HANDS - ON: INTRODUCCIÓN A LAS FUNCIONES**

# %% [markdown]
# Una vez visto la presentación ***Introducción a las funciones***, se proporciona el siguiente ***colab*** para que **el alumnado pueda practicar** haciendo uso del lenguaje de programación ***python***.

# %% [markdown]
# ## **FUNCIÓN INTEGRADA**

# %% [markdown]
# Una **función integrada** es un bloque de código reutilizable
#  predefinida en python que se utiliza para **realizar una tarea específica y están disponibles para su uso en cualquier momento** sin la necesidad de importar ningún módulo.

# %% [markdown]
# Una función integrada tiene la siguiente estructura:
#
# ```
# nombre_funcion(parametro1, parametro2, ...)
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Imprime una cadena de caracteres:

# %%
# definir función
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Devuelve la longitud de una lista:

# %%
# definir función
len([1,2,3,4,5])
# Out:
# 5

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Devuelve una lista ordenada de elementos:

# %%
# definir función
ordenada = sorted({2, 4, 8, 1, 5, 3})
print(ordenada)
# Out:
# [1, 2, 3, 4, 5, 8]

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Redondea un número según un número determinado de decimales:

# %%
import math
# definir función
print(round(math.pi, 5))
print(round(math.pi, 4))
print(round(math.pi, 3))
# Out:
# 3.14159
# 3.1416
# 3.142

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
# Devuelve el valor mínimo en una lista:

# %%
# definir función
print(min([3, 5, 6, 7, 1, 2, 4]))
# Out:
# 1

# %% [markdown]
# ## **FUNCIÓN DEFINIDA POR EL USUARIO**

# %% [markdown]
# Una **función definida por el usuario** es creada de manera personalizada para realizar tareas específicas y reutilizables en todo el programa. Este tipo de función se crea utilizando la palabra clave ` def` seguida del nombre de la función y los parámetros, si los hay.

# %% [markdown]
# Una función definida por el usuario tiene la siguiente estructura:
#
# ```
# def nombre_funcion(parametro1, parametro2, ...):
#     # Código que realiza una tarea específica
#
#     # Devolver un valor (opcional)
#     return valor
# ```

# %% [markdown]
# ### **EJEMPLO 1:**

# %% [markdown]
# Función que calcula el cuadrado de un número:

# %%
# definir función
def calcular_cuadrado(num):
  return num ** 2

# aplicación
print(calcular_cuadrado(4))
print(math.pow(4, 2))
# Out:
# 16
# 16.0

# %% [markdown]
# ### **EJEMPLO 2:**

# %% [markdown]
# Función para verificar si un número es par o impar:

# %%
# definir función
def es_par(num):
  return num % 2 == 0

# aplicación
print(f"Es par: {"Si" if es_par(3) else "No"}")
print(f"Es par: {"Si" if es_par(4) else "No"}")
# Out:
# Es par: No
# Es par: Si

# %% [markdown]
# ### **EJEMPLO 3:**

# %% [markdown]
# Función para calcular el factorial de un número:

# %%
# definir función
def calcular_factorial(num) -> int:
  if num == 0:
    return 1
  return num * calcular_factorial(num-1)

# aplicación
num = int(input("Dame un número: "))
print(f"Factorial de {num} es: {calcular_factorial(num)}")
# Out:
# Dame un número: 10
# Factorial de 10 es: 3628800

# %% [markdown]
# ### **EJEMPLO 4:**

# %% [markdown]
# Función para unir dos listas en una sola lista:

# %%
# definir listas
lista1 = [1, 2, 3]
lista2 = [4, 5, 6]

# %%
# definir función
def unir_lista(lista1, lista2):
  return lista1 + lista2

# aplicación
lista_union = unir_lista(lista1, lista2)
print(lista_union)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### **EJEMPLO 5:**

# %% [markdown]
#  Función para buscar elementos dentro de un diccionario

# %%
# definir diccionario
diccionario = {"A":"Anora", "B":"Blue Bettle", "C":"Cónclave", "D":"Drácula", "E":"Ex Máquina"}

# %%
# definir función
def buscar_elemento(diccionario : dict, clave : str) -> (int | str):
  return diccionario.get(clave)

# aplicación
consulta = input("Coloca la inicial de la película que deseas buscar: ")
resultado = buscar_elemento(diccionario, consulta.upper())
if resultado:
  print(f"Tu película es: {resultado}")
else:
  print("No tenemos una película con esa inicial en el catálogo")
# Out:
# Coloca la inicial de la película que deseas buscar: A
# Tu película es: Anora

# %% [markdown]
# ## **CHALLENGE: AGENDA CON MENÚ CRUD**

# %% [markdown]
# Una vez visto el ***Hands - On: Introducción a las funciones***, se presentan la siguientes actividades para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.

# %% [markdown]
# Dentro de la siguiente dinámica, **se utilizará el challenge del menú** para **separar por funciones los procesos del CRUD** donde **cada función será invocado dentro del ciclo donde se muestra el menú**, todo lo anterior haciendo uso de **Python**.
#
# Cada función deberá ejecutar cada operación del CRUD:
#
# *   **Ver agenda**
# *   **Crear contacto**
# *   **Consultar contacto**
# *   **Actualizar contacto**
# *   **Eliminar contacto**
# *   **Salir menú**

# %% [markdown]
# **IMPORTANTE:** Para su revisión, **es indispensable que los apartados anteriores se encuentren llenados con el código visto durante la sesión.**

# %% [markdown]
# ### **INSTRUCCIONES:**

# %% [markdown]
# **1. Crea la Agenda:** Construye la agenda con los registros utilizados en las prácticas anteriores.

# %%
# Definir agenda
agenda = [{'Nombre': 'Ricardo',
  'Telefono': '+52 6571257790',
  'Correo': 'rich.gomez@gmail.com'},
 {'Nombre': 'Pablo',
  'Telefono': '+52 6572023182',
  'Correo': 'mata.pablo@yahoo.com.mx'},
 {'Nombre': 'Sara',
  'Telefono': '+52 6572706692',
  'Correo': 'sara.mendoza@pm.me'}]

# %% [markdown]
# **2. Define una función que muestre las opciones del menú CRUD:**
#
#    * Crea una función que muestre el menú CRUD para la agenda con las opciones:
#
#    ```
#    Menú CRUD - Agenda:
#
#    1. Ver agenda
#    2. Crear contacto
#    3. Consultar contacto
#    4. Actualizar contacto
#    5. Eliminar contacto
#    6. Salir menú
#    ```

# %%
# Crear función menú opciones
def imprimir_menu_opciones():
  menu = """
  Menú CRUD - Agenda:

  1. Ver agenda
  2. Crear contacto
  3. Consultar contacto
  4. Actualizar contacto
  5. Eliminar contacto
  6. Salir menú
  """
  print(menu)

imprimir_menu_opciones()
# Out:
#   Menú CRUD - Agenda:
#
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú

# %% [markdown]
# **3. Define una función que imprima todos los contactos de la agenda:**
#
#    * Crea una función que realice un ciclo for que recorra y muestre cada contacto de la agenda.
#    * Dentro del ciclo, muestra el número de contacto por cada iteración.

# %%
# Crear función mostrar agenda
def mostrar_agenda():
  for i in range(len(agenda)):
    contacto = agenda[i]
    print(f"Contacto {i + 1}: \n {contacto["Nombre"]} \n {contacto["Telefono"]} \n {contacto["Correo"]}")

mostrar_agenda()
# Out:
# Contacto 1:
#  Ricardo
#  +52 6571257790
#  rich.gomez@gmail.com
# Contacto 2:
#  Pablo
#  +52 6572023182
#  mata.pablo@yahoo.com.mx
# Contacto 3:
#  Sara
#  +52 6572706692
#  sara.mendoza@pm.me

# %% [markdown]
# **4. Define una función para crear un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre, teléfono y correo para un contacto.
#    * Guarda estos datos en un diccionario llamado contacto.
#    * Imprime el mensaje "Contacto creado con éxito".

# %%
# Crear función crear contacto
def crear_contacto():
  nombre = input("¿Cuál es tu nombre?: ").capitalize()
  telefono = input("¿Cuál es tu teléfono?: ")
  correo = input("¿Cuál es tu correo?: ")

  nuevo_contacto = {
      "Nombre":nombre,
      "Telefono": telefono,
      "Correo": correo}
  agenda.append(nuevo_contacto)

  print("Contacto creado con éxito")

#crear_contacto()

# %% [markdown]
# **5. Define una función para consultar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a consultar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces imprime el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función consultar contacto
def consultar_contacto():
  encontrado = False
  consulta = input("¿Qué contacto deseas buscar?: ").capitalize()
  for contacto in agenda:
    if contacto["Nombre"] == consulta:
      encontrado = True
      print(f"Contacto encontrado: \n {contacto["Nombre"]} \n {contacto["Telefono"]} \n {contacto["Correo"]}")
      break
  if not encontrado:
    print("Contacto no encontrado")

consultar_contacto()
# Out:
# ¿Qué contacto deseas buscar?: Sara
# Contacto encontrado:
#  Sara
#  +52 6572706692
#  sara.mendoza@pm.me

# %% [markdown]
# **6. Define una función para actualizar un contacto de la agenda:**
#
#  (Dada la complejidad y extensión de este punto se separará por partes).
#
#    * Crea una función que visualice un menú que contenga las siguientes opciones:
#
#    ```
#    Menú actualizar contacto:
#
#    1. Actualizar nombre
#    2. Actualizar teléfono
#    3. Actualziar correo
#    4. Salir del menú
#    ```

# %%
# Crear función menú para actualizar contacto
def imprimir_menu_actualizar():
  menu = """
  Menú actualizar contacto:

  1. Actualizar nombre
  2. Actualizar teléfono
  3. Actualizar correo
  4. Salir del menú
  """
  print(menu)

imprimir_menu_opciones()
# Out:
#   Menú CRUD - Agenda:
#
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú

# %% [markdown]
#    * Crea una función que realice un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces retorna el contacto encontrado.
#    * De lo contrario, entonces retorna `None`.

# %%
# Crear función buscador contacto para actualizar contacto
def buscar_contacto() -> dict:
  busqueda = input("Escribe el nombre del contacto a buscar: ").capitalize()
  for contacto in agenda:
    if contacto["Nombre"] == busqueda:
      print(f"Contacto encontrado: \n {contacto["Nombre"]} \n {contacto["Telefono"]} \n {contacto["Correo"]}")
      return contacto
  return None

buscar_contacto()
# Out:
# Escribe el nombre del contacto a buscar: Pablo
# Contacto encontrado:
#  Pablo
#  +52 6572023182
#  mata.pablo@yahoo.com.mx
# {'Nombre': 'Pablo',
#  'Telefono': '+52 6572023182',
#  'Correo': 'mata.pablo@yahoo.com.mx'}

# %% [markdown]
#    * Crea una función para cada opción a escojer, modificando ya sea el nombre, el teléfono o el correo del contacto encontrado por nuevos registros.
#    * Por cada registro nuevo ingresado, imprime el contacto para visualizar los cambios.

# %%
# Crear función actualizar nombre para actualizar contacto
def actualizar_nombre(contacto):
  nuevo_nombre = input("Escribe el nuevo nombre: ").capitalize()
  contacto["Nombre"] = nuevo_nombre
  print(f"Nombre actualizado correctamente: {contacto}")

# %%
# Crear función actualizar telefono para actualizar contacto
def actualizar_numero(contacto):
  nuevo_numero = input("Escribe el nuevo número: ")
  contacto["Telefono"] = nuevo_numero
  print(f"Número actualizado correctamente: {contacto}")

# %%
# Crear función actualizar correo para actualizar contacto
def actualizar_correo(contacto):
  nuevo_correo = input("Escribe el nuevo correo: ")
  contacto["Correo"] = nuevo_correo
  print(f"Correo actualizado correctamente: {contacto}")

# %% [markdown]
#    * Crea una función que integre las funciones creadas anteriormente a través de un ciclo while para un menú de actualizar un contacto.
#    * Pide al usuario que ingrese el nombre del contacto a actualizar.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función actualizar contacto
def actualizar_contacto():
    contacto = buscar_contacto()
    if contacto is None:
      print("Contacto no encontrado")
    else:
      while True:
        imprimir_menu_actualizar()
        opcion = int(input("Elige una opción: "))
        match opcion:
          case 1:
            actualizar_nombre(contacto)
          case 2:
            actualizar_numero(contacto)
          case 3:
            actualizar_correo(contacto)
          case 4:
            print("Saliendo del menú")
            break
          case _:
            print("Opción no válida")

#actualizar_contacto()

# %% [markdown]
# **7. Define una función para eliminar un contacto de la agenda:**
#
#    * Crea una función que pida al usuario que ingrese el nombre del contacto a eliminar.
#    * Realiza un ciclo for para la búsqueda del nombre dentro de la agenda.
#    * Sí el ciclo encuentra la búsqueda, entonces elimina el contacto encontrado.
#    * De lo contrario, entonces imprime "Contacto no encontrado".

# %%
# Crear función eliminar contacto
def eliminar_contacto():
  nombre = input("Escribe el nombre del contacto a eliminar: ").title()
  nombre_encontrado = False
  for i in agenda:
    if i["Nombre"] == nombre:
      contacto = i
      nombre_encontrado = True
      break

  if nombre_encontrado:
    agenda.remove(contacto)
    print("Contacto eliminado correctamente")
  else:
    print("Contacto no encontrado")

# %% [markdown]
# **8. Junta todas las funciones del menú CRUD dentro de una función:**
#
#    * Crea una función crear un menú a través de un ciclo while.
#    * Solicita al usuario una opción mostrada en el menú, si el usuario no coloca la opción correcta, entonces muestra el mensaje "Opción no encontrada".
#    * Dada la opción escojida, ingresa a una función definida con anterioridad que corresponda a su operación a realizar.
#    * Define en la última opción un `break` para salir del menú.

# %%
# Crear función menú agenda
while True:
  imprimir_menu_opciones()
  opcion = int(input("Elige una opción: "))
  match opcion:
    case 1:
      mostrar_agenda()
    case 2:
      crear_contacto()
    case 3:
      consultar_contacto()
    case 4:
      actualizar_contacto()
    case 5:
      eliminar_contacto()
    case 6:
      print("Hasta pronto")
      break
    case _:
      print("Opción no válida")
# Out:
#   Menú CRUD - Agenda:
#
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#
# Elige una opción: 1
# Contacto 1:
#  Ricardo
#  +52 6571257790
#  rich.gomez@gmail.com
# Contacto 2:
#  Pablo
#  +52 6572023182
#  mata.pablo@yahoo.com.mx
# Contacto 3:
#  Sara
#  +52 6572706692
#  sara.mendoza@pm.me
#
#   Menú CRUD - Agenda:
#
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#
# Elige una opción: 2
# ¿Cuál es tu nombre?: yAEL
# ¿Cuál es tu teléfono?: 5546789200
# ¿Cuál es tu correo?: juanes2008@gmail.com
# Contacto creado con éxito
#
#   Menú CRUD - Agenda:
#
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#
# Elige una opción: 3
# ¿Qué contacto deseas buscar?: yael
# Contacto encontrado:
#  Yael
#  5546789200
#  juanes2008@gmail.com
#
#   Menú CRUD - Agenda:
#
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#
# Elige una opción: 4
# Escribe el nombre del contacto a buscar: Pablo
# Contacto encontrado:
#  Pablo
#  +52 6572023182
#  mata.pablo@yahoo.com.mx
#
#   Menú actualizar contacto:
#
#   1. Actualizar nombre
#   2. Actualizar teléfono
#   3. Actualizar correo
#   4. Salir del menú
#
# Elige una opción: 1
# Escribe el nuevo nombre: Martín
# Nombre actualizado correctamente: {'Nombre': 'Martín', 'Telefono': '+52 6572023182', 'Correo': 'mata.pablo@yahoo.com.mx'}
#
#   Menú actualizar contacto:
#
#   1. Actualizar nombre
#   2. Actualizar teléfono
#   3. Actualizar correo
#   4. Salir del menú
#
# Elige una opción: 2
# Escribe el nuevo número: 5546728900
# Número actualizado correctamente: {'Nombre': 'Martín', 'Telefono': '5546728900', 'Correo': 'mata.pablo@yahoo.com.mx'}
#
#   Menú actualizar contacto:
#
#   1. Actualizar nombre
#   2. Actualizar teléfono
#   3. Actualizar correo
#   4. Salir del menú
#
# Elige una opción: 3
# Escribe el nuevo correo: morin.martin@outlook.com
# Correo actualizado correctamente: {'Nombre': 'Martín', 'Telefono': '5546728900', 'Correo': 'morin.martin@outlook.com'}
#
#   Menú actualizar contacto:
#
#   1. Actualizar nombre
#   2. Actualizar teléfono
#   3. Actualizar correo
#   4. Salir del menú
#
# Elige una opción: 4
# Saliendo del menú
#
#   Menú CRUD - Agenda:
#
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#
# Elige una opción: 4
# Escribe el nombre del contacto a buscar: Pablo
# Contacto no encontrado
#
#   Menú CRUD - Agenda:
#
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#
# Elige una opción: 5
# Escribe el nombre del contacto a eliminar: Yael
# Contacto eliminado correctamente
#
#   Menú CRUD - Agenda:
#
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#
# Elige una opción: 1
# Contacto 1:
#  Ricardo
#  +52 6571257790
#  rich.gomez@gmail.com
# Contacto 2:
#  Martín
#  5546728900
#  morin.martin@outlook.com
# Contacto 3:
#  Sara
#  +52 6572706692
#  sara.mendoza@pm.me
#
#   Menú CRUD - Agenda:
#
#   1. Ver agenda
#   2. Crear contacto
#   3. Consultar contacto
#   4. Actualizar contacto
#   5. Eliminar contacto
#   6. Salir menú
#
# Elige una opción: 6
# Hasta pronto
